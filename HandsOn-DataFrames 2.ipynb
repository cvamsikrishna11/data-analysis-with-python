# %% [markdown]
# # Memory optimization and cleaning the data

# %%
import pandas as pd

# %%
df = pd.read_csv('pandas/employees.csv')
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df['Start Date'].head(3)
# Out:
# 0     8/6/1993
# 1    3/31/1996
# 2    4/23/1993
# Name: Start Date, dtype: object

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 62.6+ KB

# %%
df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-06 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-06 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-04-06 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-04-06 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-04-06 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-04-06 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-04-06 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
df['Senior Management'] = df['Senior Management'].astype('bool')

# %%
df['Gender'] = df['Gender'].astype('category')

# %%
# Check the total memory usage earlier and now
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
## Now do all above operations with less code, we can parse the dates while converting into DF
df = pd.read_csv('pandas/employees.csv', parse_dates=['Start Date','Last Login Time'])
# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team']=df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %% [markdown]
# ## Filter a DataFrame based on a condition

# %%
df = pd.read_csv('pandas/employees.csv', parse_dates=['Start Date','Last Login Time'])
# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team']=df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df[df['Gender'] == 'Male']
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2020-04-06 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2020-04-06 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2020-04-06 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2020-04-06 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2020-04-06 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2020-04-06 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2020-04-06 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2020-04-06 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %%
# Another way to filter on condition
mask = df['Team'] == 'Finance'
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-06 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2020-04-06 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2020-04-06 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2020-04-06 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2020-04-06 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2020-04-06 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2020-04-06 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2020-04-06 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2020-04-06 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 True  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %%
# When checking boolean value we don't need to check the condition, we can directly pass the column name as outer df will only consider the True values
df[df['Senior Management']]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2020-04-06 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-06 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2020-04-06 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2020-04-06 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-04-06 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2020-04-06 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2020-04-06 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2020-04-06 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 6                 True          Product
# ..                 ...              ...
# 991               True        Marketing
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 999               True            Sales
#
# [535 rows x 8 columns]

# %%
# Condition not match
df[df['Team'] != 'Marketing']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-06 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-06 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-04-06 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2020-04-06 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-04-06 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-04-06 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-04-06 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-04-06 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-04-06 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# 6                 True               Product
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [859 rows x 8 columns]

# %%
df[df['Salary'] > 100000]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-06 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-06 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-04-06 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2020-04-06 06:51:00  139852    7.524
# ..         ...     ...        ...                 ...     ...      ...
# 990      Robin  Female 1987-07-24 2020-04-06 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2020-04-06 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-04-06 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2020-04-06 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2020-04-06 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# 9                 True  Business Development
# ..                 ...                   ...
# 990               True       Client Services
# 991               True             Marketing
# 992               True               Finance
# 995              False          Distribution
# 999               True                 Sales
#
# [409 rows x 8 columns]

# %%
df[df['Bonus %'] < 1.5]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24 2020-04-06 16:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05 2020-04-06 06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11 2020-04-06 07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14 2020-04-06 20:13:00  107391    1.260
# 175     Willie    Male 1998-02-17 2020-04-06 20:20:00  146651    1.451
# 189   Clarence    Male 1998-05-02 2020-04-06 03:16:00   85700    1.215
# 217    Douglas    Male 1999-09-03 2020-04-06 16:00:00   83341    1.015
# 273   Nicholas    Male 1994-04-12 2020-04-06 20:21:00   74669    1.113
# 279       Ruby  Female 2000-11-08 2020-04-06 19:35:00  105946    1.139
# 365     Gloria     NaN 1983-07-19 2020-04-06 01:57:00  140885    1.113
# 445      Chris    Male 2006-12-12 2020-04-06 01:57:00   71642    1.496
# 481        NaN  Female 2013-04-27 2020-04-06 06:40:00   93847    1.085
# 527      Helen     NaN 1993-12-02 2020-04-06 13:42:00   45724    1.022
# 570      Kelly  Female 1996-08-16 2020-04-06 03:09:00   41427    1.431
# 578     Amanda  Female 1982-03-17 2020-04-06 23:46:00  107111    1.438
# 579     Harold    Male 2010-10-18 2020-04-06 20:45:00   65673    1.187
# 617      Kathy  Female 2001-01-14 2020-04-06 05:11:00   45682    1.451
# 618      Peter    Male 1992-11-24 2020-04-06 17:43:00   69297    1.268
# 638    Frances  Female 1996-11-12 2020-04-06 18:08:00  112467    1.433
# 652     Willie    Male 2009-12-05 2020-04-06 05:39:00  141932    1.017
# 708      Steve    Male 2002-01-11 2020-04-06 21:17:00   51821    1.197
# 732      Henry    Male 1986-05-12 2020-04-06 02:04:00   59943    1.432
# 734        NaN  Female 1994-12-18 2020-04-06 20:42:00  138807    1.400
# 746     Gloria  Female 2004-08-19 2020-04-06 10:31:00   46602    1.027
# 912        Joe    Male 1998-12-08 2020-04-06 10:28:00  126120    1.020
# 929    Theresa  Female 2001-04-27 2020-04-06 21:17:00   75661    1.079
# 954        Joe    Male 1980-01-19 2020-04-06 16:06:00  119667    1.148
# 997    Russell    Male 2013-05-20 2020-04-06 12:39:00   96914    1.421
#
#      Senior Management                  Team
# 4                 True       Client Services
# 15               False               Product
# 58                True           Engineering
# 77                True             Marketing
# 175               True           Engineering
# 189              False                 Sales
# 217               True       Client Services
# 273               True               Product
# 279              False  Business Development
# 365              False       Human Resources
# 445              False                   NaN
# 481               True  Business Development
# 527              False               Product
# 570              False               Product
# 578               True               Product
# 579               True                 Legal
# 617               True             Marketing
# 618              False               Finance
# 638              False  Business Development
# 652               True           Engineering
# 708               True                 Legal
# 732              False               Finance
# 734               True       Human Resources
# 746               True  Business Development
# 912              False                   NaN
# 929               True                 Legal
# 954               True               Finance
# 997              False               Product

# %%
df[df['Start Date'] <= '1985-01-01']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2020-04-06 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2020-04-06 01:08:00  112807   17.492
# 18       Diana  Female 1981-10-23 2020-04-06 10:27:00  132940   19.082
# 28       Terry    Male 1981-11-27 2020-04-06 18:30:00  124008   13.464
# 37       Linda  Female 1981-10-19 2020-04-06 20:49:00   57427    9.557
# ..         ...     ...        ...                 ...     ...      ...
# 982       Rose  Female 1982-04-06 2020-04-06 10:43:00   91411    8.639
# 983       John    Male 1982-12-23 2020-04-06 22:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10 2020-04-06 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2020-04-06 07:04:00   82871   17.999
# 996    Phillip    Male 1984-01-31 2020-04-06 06:30:00   42392   19.675
#
#      Senior Management             Team
# 10                True              NaN
# 12                True  Human Resources
# 18               False  Client Services
# 28                True  Client Services
# 37                True  Client Services
# ..                 ...              ...
# 982               True  Human Resources
# 983              False      Engineering
# 985              False            Legal
# 986              False        Marketing
# 996              False          Finance
#
# [133 rows x 8 columns]

# %% [markdown]
# ## Filter with more than one condition(AND - &)

# %%
df = pd.read_csv('pandas/employees.csv', parse_dates=['Start Date','Last Login Time'])
# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team']=df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask1 = df['Gender'] == 'Male'
mask2 = df['Team'] == 'Marketing'
df[mask1 & mask2]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2020-04-06 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2020-04-06 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2020-04-06 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2020-04-06 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2020-04-06 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2020-04-06 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2020-04-06 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2020-04-06 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2020-04-06 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2020-04-06 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2020-04-06 09:45:00   55281    4.935
# 216    Matthew   Male 2013-07-31 2020-04-06 08:04:00  142373    2.462
# 252      Ralph   Male 2004-11-11 2020-04-06 01:35:00   71896    4.232
# 274     Howard   Male 1982-10-05 2020-04-06 07:22:00   97490    5.460
# 293      Jesse   Male 1999-10-25 2020-04-06 15:35:00  118733    9.653
# 309   Benjamin   Male 1984-09-11 2020-04-06 06:37:00   84810   15.794
# 327      Aaron   Male 1994-01-29 2020-04-06 18:48:00   58755    5.097
# 353        NaN   Male 1997-04-22 2020-04-06 21:36:00   65078    3.095
# 403      Craig   Male 1984-02-08 2020-04-06 04:45:00  113506   19.642
# 413     Johnny   Male 1992-09-14 2020-04-06 08:21:00  115194    5.861
# 452      Scott   Male 2012-11-17 2020-04-06 14:47:00  146812    1.965
# 454        NaN   Male 1995-02-21 2020-04-06 00:26:00  136602   10.429
# 461     Jeremy   Male 2001-08-09 2020-04-06 03:56:00   43354   13.946
# 464   Lawrence   Male 2005-05-13 2020-04-06 01:25:00   74640   18.641
# 484        Joe   Male 2000-04-14 2020-04-06 15:14:00   50645   11.119
# 496     Johnny   Male 2016-02-26 2020-04-06 19:39:00   76394    5.437
# 503      Roger   Male 2015-08-03 2020-04-06 16:56:00  125033    4.887
# 544      Roger   Male 2010-07-03 2020-04-06 17:11:00  105689   13.320
# 550    Gregory   Male 1984-06-18 2020-04-06 03:46:00   82726   16.304
# 556     Arthur   Male 2014-12-16 2020-04-06 16:56:00   66819    6.639
# 571   Jonathan   Male 1995-04-06 2020-04-06 22:38:00   56993   18.623
# 581     Ernest   Male 1990-01-28 2020-04-06 00:08:00   81919   15.118
# 696     Samuel   Male 2012-05-25 2020-04-06 16:40:00   85550   11.593
# 722     Joshua   Male 1997-06-27 2020-04-06 15:23:00   95003    5.197
# 798   Lawrence   Male 1984-10-01 2020-04-06 14:06:00  102589   17.952
# 860    Phillip   Male 1984-10-07 2020-04-06 11:05:00   36837   14.660
# 867       Earl   Male 2013-06-15 2020-04-06 03:00:00   48046    7.737
# 899     Walter   Male 1992-05-21 2020-04-06 00:39:00  144701   16.323
# 947        NaN   Male 2012-07-30 2020-04-06 15:07:00  107351    5.329
# 994     George   Male 2013-06-21 2020-04-06 17:47:00   98874    4.479
#
#      Senior Management       Team
# 0                 True  Marketing
# 21               False  Marketing
# 26                True  Marketing
# 74               False  Marketing
# 77                True  Marketing
# 101               True  Marketing
# 104              False  Marketing
# 112              False  Marketing
# 119              False  Marketing
# 150              False  Marketing
# 187              False  Marketing
# 204               True  Marketing
# 216              False  Marketing
# 252               True  Marketing
# 274               True  Marketing
# 293              False  Marketing
# 309              False  Marketing
# 327               True  Marketing
# 353               True  Marketing
# 403              False  Marketing
# 413               True  Marketing
# 452               True  Marketing
# 454               True  Marketing
# 461              False  Marketing
# 464              False  Marketing
# 484              False  Marketing
# 496               True  Marketing
# 503               True  Marketing
# 544               True  Marketing
# 550               True  Marketing
# 556               True  Marketing
# 571              False  Marketing
# 581              False  Marketing
# 696               True  Marketing
# 722               True  Marketing
# 798               True  Marketing
# 860              False  Marketing
# 867              False  Marketing
# 899               True  Marketing
# 947               True  Marketing
# 994               True  Marketing

# %% [markdown]
# ## Filter with more than one condition(OR - |)

# %%
df = pd.read_csv('pandas/employees.csv', parse_dates=['Start Date','Last Login Time'])
# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team']=df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask1 = df['Senior Management']
mask2 = df['Start Date'] < '1990-01-01'

df[mask1 | mask2]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2020-04-06 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-06 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-04-06 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2020-04-06 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2020-04-06 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2020-04-06 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2020-04-06 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2020-04-06 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 5                False            Legal
# ..                 ...              ...
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 996              False          Finance
# 999               True            Sales
#
# [653 rows x 8 columns]

# %%
mask1 = df['First Name'] =='Robert'
mask2 = df['Team'] == 'Client Services'
mask3 = df['Start Date'] > '2016-06-01'

df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2020-04-06 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2020-04-06 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2020-04-06 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2020-04-06 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# ## The .isin() method

# %%
df = pd.read_csv('pandas/employees.csv', parse_dates=['Start Date','Last Login Time'])
# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team']=df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
# General way, but would be difficult when we have lots of values to compare
mask1 = df['Team'] == 'Legal'
mask2 = df['Team'] == 'Sales'
mask3 = df ['Team'] == 'Product'

df[mask1 | mask2 | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2020-04-06 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2020-04-06 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2020-04-06 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2020-04-06 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2020-04-06 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2020-04-06 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2020-04-06 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2020-04-06 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2020-04-06 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2020-04-06 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %%
# Efficient way
mask = df['Team'].isin(['Legal', 'Sales', 'Product', 'Marketing'])
df[mask]
# we can also compare isin in between two series values
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 5       Dennis    Male 1987-04-18 2020-04-06 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2020-04-06 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2020-04-06 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2020-04-06 23:40:00  109831    5.831
# ..         ...     ...        ...                 ...     ...      ...
# 989     Justin     NaN 1991-02-10 2020-04-06 16:58:00   38344    3.794
# 991       Rose  Female 2002-08-25 2020-04-06 05:12:00  134505   11.051
# 994     George    Male 2013-06-21 2020-04-06 17:47:00   98874    4.479
# 997    Russell    Male 2013-05-20 2020-04-06 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2020-04-06 18:24:00  129949   10.169
#
#      Senior Management       Team
# 0                 True  Marketing
# 5                False      Legal
# 6                 True    Product
# 11                True      Legal
# 13               False      Sales
# ..                 ...        ...
# 989              False      Legal
# 991               True  Marketing
# 994               True  Marketing
# 997              False    Product
# 999               True      Sales
#
# [375 rows x 8 columns]

# %% [markdown]
# ## The .isnull() and .notnull() methods

# %%
df = pd.read_csv('pandas/employees.csv', parse_dates=['Start Date','Last Login Time'])
# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team']=df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask = df['Team'].isnull()
df[mask]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2020-04-06 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2020-04-06 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2020-04-06 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2020-04-06 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2020-04-06 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2020-04-06 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2020-04-06 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2020-04-06 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2020-04-06 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2020-04-06 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2020-04-06 06:06:00   66067   10.957
# 382          NaN  Female 1996-04-18 2020-04-06 15:57:00  107024   12.182
# 434        Joyce  Female 1995-02-07 2020-04-06 07:38:00   50701   14.227
# 438        Jason    Male 1998-11-20 2020-04-06 14:54:00   69244    6.220
# 445        Chris    Male 2006-12-12 2020-04-06 01:57:00   71642    1.496
# 479      Richard    Male 1997-07-04 2020-04-06 11:47:00   47647   18.787
# 512        Wanda  Female 1993-04-06 2020-04-06 03:11:00   78883   19.695
# 513        Jimmy    Male 2013-11-19 2020-04-06 19:29:00   63549   19.624
# 520        Peter    Male 2003-02-22 2020-04-06 09:09:00   56580    8.411
# 567          NaN  Female 1980-04-01 2020-04-06 20:04:00   48141   12.605
# 573     Kimberly  Female 1981-12-30 2020-04-06 04:51:00   81800    5.435
# 580        Harry    Male 1985-01-27 2020-04-06 20:18:00   65482   18.089
# 626          NaN  Female 1997-04-13 2020-04-06 08:03:00  131755    2.930
# 634         Carl    Male 1987-03-30 2020-04-06 17:59:00   75598   19.289
# 635        Randy    Male 2000-09-27 2020-04-06 03:04:00   89831   13.047
# 647       Donald    Male 1988-04-06 2020-04-06 10:00:00  122920    5.320
# 669       Joseph     NaN 1982-03-28 2020-04-06 13:05:00   86564   11.879
# 684        Alice  Female 2016-01-21 2020-04-06 17:07:00  117787   10.485
# 706         Todd    Male 1993-07-04 2020-04-06 18:53:00  128175   18.473
# 726       Daniel    Male 2016-02-29 2020-04-06 04:04:00   77287   13.000
# 753      Antonio    Male 1999-06-06 2020-04-06 22:54:00   41928    5.478
# 774          NaN  Female 2000-06-18 2020-04-06 07:36:00  106428   10.867
# 781     Lawrence    Male 1995-07-03 2020-04-06 22:55:00   46378    9.127
# 794       Nicole  Female 2004-03-01 2020-04-06 17:17:00   44021   10.286
# 826          NaN     NaN 1988-08-01 2020-04-06 01:35:00   87103    5.665
# 850      Charles    Male 1997-09-03 2020-04-06 10:04:00  148291    6.002
# 851        Bobby    Male 1996-08-19 2020-04-06 01:16:00  147842   16.158
# 853      Mildred  Female 2007-04-06 2020-04-06 22:06:00  139284   11.390
# 855      Phillip     NaN 2003-10-20 2020-04-06 11:09:00   89700    2.277
# 864         Ryan    Male 2012-11-16 2020-04-06 13:47:00   57292    6.010
# 912          Joe    Male 1998-12-08 2020-04-06 10:28:00  126120    1.020
# 951          NaN  Female 2010-09-14 2020-04-06 05:19:00  143638    9.662
#
#      Senior Management Team
# 1                 True  NaN
# 10                True  NaN
# 23                True  NaN
# 32                True  NaN
# 91               False  NaN
# 109              False  NaN
# 139               True  NaN
# 199               True  NaN
# 258              False  NaN
# 290               True  NaN
# 314              False  NaN
# 367               True  NaN
# 382               True  NaN
# 434               True  NaN
# 438               True  NaN
# 445              False  NaN
# 479               True  NaN
# 512              False  NaN
# 513              False  NaN
# 520               True  NaN
# 567               True  NaN
# 573               True  NaN
# 580              False  NaN
# 626               True  NaN
# 634              False  NaN
# 635               True  NaN
# 647              False  NaN
# 669               True  NaN
# 684              False  NaN
# 706               True  NaN
# 726               True  NaN
# 753               True  NaN
# 774               True  NaN
# 781              False  NaN
# 794              False  NaN
# 826               True  NaN
# 850              False  NaN
# 851               True  NaN
# 853               True  NaN
# 855               True  NaN
# 864              False  NaN
# 912              False  NaN
# 951               True  NaN

# %%
mask = df['Gender'].notnull()
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-04-06 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-04-06 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2020-04-06 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2020-04-06 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-04-06 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-04-06 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-04-06 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [855 rows x 8 columns]

# %% [markdown]
# ## The .between() method

# %%
df = pd.read_csv('pandas/employees.csv', parse_dates=['Start Date','Last Login Time'])
# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team']=df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask = df['Salary'].between(60000, 70000)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2020-04-06 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2020-04-06 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2020-04-06 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2020-04-06 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2020-04-06 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2020-04-06 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2020-04-06 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2020-04-06 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2020-04-06 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# 6                 True               Product
# 10                True                   NaN
# 20                True                 Legal
# 41                True  Business Development
# ..                 ...                   ...
# 965              False       Client Services
# 970               True               Product
# 974               True       Client Services
# 978              False       Human Resources
# 998              False  Business Development
#
# [86 rows x 8 columns]

# %%
mask = df['Bonus %'].between(2.0, 5.0)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2020-04-06 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2020-04-06 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2020-04-06 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 2020-04-06 14:01:00   48866    4.271
# ..         ...     ...        ...                 ...     ...      ...
# 943      Wayne    Male 2006-09-08 2020-04-06 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2020-04-06 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2020-04-06 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2020-04-06 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2020-04-06 17:47:00   98874    4.479
#
#      Senior Management          Team
# 1                 True           NaN
# 20                True         Legal
# 40                True  Distribution
# 49               False         Sales
# 60               False  Distribution
# ..                 ...           ...
# 943              False   Engineering
# 961              False         Legal
# 976               True         Legal
# 989              False         Legal
# 994               True     Marketing
#
# [169 rows x 8 columns]

# %%
mask = df['Start Date'].between('2010-01-01', '2020-01-01')
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 7          NaN  Female 2015-07-20 2020-04-06 10:43:00   45906   11.598
# 15     Lillian  Female 2016-06-05 2020-04-06 06:09:00   59414    1.256
# 16      Jeremy    Male 2010-09-21 2020-04-06 05:56:00   90370    7.369
# 19       Donna  Female 2010-07-22 2020-04-06 03:48:00   81014    1.894
# 22      Joshua     NaN 2012-03-08 2020-04-06 01:58:00   90816   18.816
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2020-04-06 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2020-04-06 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2020-04-06 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-04-06 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-04-06 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 7                 True               Finance
# 15               False               Product
# 16               False       Human Resources
# 19               False               Product
# 22                True       Client Services
# ..                 ...                   ...
# 994               True             Marketing
# 995              False          Distribution
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [180 rows x 8 columns]

# %%
mask = df['Last Login Time'].between('2020-04-06 08:30:00', '2020-04-06 12:30:00')
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
# 7          NaN  Female 2015-07-20 2020-04-06 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2020-04-06 09:01:00   63241   15.132
# 18       Diana  Female 1981-10-23 2020-04-06 10:27:00  132940   19.082
# 33        Jean  Female 1993-12-18 2020-04-06 09:07:00  119082   16.180
# ..         ...     ...        ...                 ...     ...      ...
# 963        Ann  Female 1994-09-23 2020-04-06 11:15:00   89443   17.940
# 977      Sarah  Female 1995-12-04 2020-04-06 09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06 2020-04-06 10:43:00   91411    8.639
# 988      Alice  Female 2004-10-05 2020-04-06 09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16 2020-04-06 08:35:00  112769   11.625
#
#      Senior Management                  Team
# 2                False               Finance
# 7                 True               Finance
# 10                True                   NaN
# 18               False       Client Services
# 33               False  Business Development
# ..                 ...                   ...
# 963               True                 Sales
# 977              False               Product
# 982               True       Human Resources
# 988              False       Human Resources
# 992               True               Finance
#
# [159 rows x 8 columns]

# %% [markdown]
# ## The .duplicated() method

# %%
df = pd.read_csv('pandas/employees.csv', parse_dates=['Start Date','Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team']=df['Team'].astype('category')
df.sort_values('First Name', inplace=True)
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2020-04-06 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2020-04-06 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2020-04-06 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
df['First Name'].duplicated(keep='first')
df['First Name'].duplicated(keep='last')
df[df['First Name'].duplicated(keep=False)]
df[~df['First Name'].duplicated(keep=False)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2020-04-06 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2020-04-06 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2020-04-06 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2020-04-06 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2020-04-06 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2020-04-06 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2020-04-06 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2020-04-06 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2020-04-06 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %% [markdown]
# ## The .drop_duplicates() method

# %%
df = pd.read_csv('pandas/employees.csv', parse_dates=['Start Date','Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team']=df['Team'].astype('category')
df.sort_values('First Name', inplace=True)
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2020-04-06 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2020-04-06 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2020-04-06 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
len(df)
# Out:
# 1000

# %%
# still having the same length, coz it will checks for duplicates in entire row, not for single column
df.drop_duplicates()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-04-06 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2020-04-06 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-04-06 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2020-04-06 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2020-04-06 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2020-04-06 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2020-04-06 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2020-04-06 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2020-04-06 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2020-04-06 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution
# ..                 ...              ...
# 902               True     Distribution
# 925               True            Sales
# 946               True     Distribution
# 947               True        Marketing
# 951               True              NaN
#
# [1000 rows x 8 columns]

# %%
df.drop_duplicates(['First Name'], keep='first')
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-04-06 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2020-04-06 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2020-04-06 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2020-04-06 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2020-04-06 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2020-04-06 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2020-04-06 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2020-04-06 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2020-04-06 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2020-04-06 10:43:00   45906   11.598
#
#      Senior Management             Team
# 101               True        Marketing
# 137              False     Distribution
# 300               True      Engineering
# 372               True      Engineering
# 988              False  Human Resources
# ..                 ...              ...
# 433               True            Legal
# 177               True     Distribution
# 820               True  Human Resources
# 450              False            Legal
# 7                 True          Finance
#
# [201 rows x 8 columns]

# %%
df.drop_duplicates(['First Name'], keep='last')
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 937      Aaron     NaN 1986-01-22 2020-04-06 19:39:00   63126   18.424
# 538       Adam    Male 2010-10-08 2020-04-06 21:53:00   45181    3.491
# 610       Alan    Male 2012-02-17 2020-04-06 00:26:00   41453   10.084
# 959     Albert    Male 1992-09-19 2020-04-06 02:35:00   45094    5.850
# 693      Alice  Female 1995-10-16 2020-04-06 21:19:00   92799    2.782
# ..         ...     ...        ...                 ...     ...      ...
# 512      Wanda  Female 1993-04-06 2020-04-06 03:11:00   78883   19.695
# 637      Wayne    Male 2009-09-02 2020-04-06 01:37:00  126956   18.396
# 127    William    Male 2002-09-29 2020-04-06 16:09:00   66521    5.830
# 652     Willie    Male 2009-12-05 2020-04-06 05:39:00  141932    1.017
# 951        NaN  Female 2010-09-14 2020-04-06 05:19:00  143638    9.662
#
#      Senior Management                  Team
# 937              False       Client Services
# 538              False       Human Resources
# 610              False               Product
# 959               True  Business Development
# 693              False                 Sales
# ..                 ...                   ...
# 512              False                   NaN
# 637              False       Human Resources
# 127              False       Human Resources
# 652               True           Engineering
# 951               True                   NaN
#
# [201 rows x 8 columns]

# %%
df.drop_duplicates(['First Name'], keep=False)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2020-04-06 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2020-04-06 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2020-04-06 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2020-04-06 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2020-04-06 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2020-04-06 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2020-04-06 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2020-04-06 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2020-04-06 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %%
# Coz team values are always duplicate
df.drop_duplicates(subset=['Team'], keep=False)
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
df.drop_duplicates(subset=['First Name','Team'])
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-04-06 10:20:00   61602   11.849
# 440      Aaron    Male 1990-07-22 2020-04-06 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2020-04-06 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2020-04-06 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2020-04-06 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 149        NaN  Female 2014-08-17 2020-04-06 14:00:00   86230    8.578
# 157        NaN  Female 2005-07-27 2020-04-06 08:32:00   79536   14.443
# 269        NaN  Female 1992-08-02 2020-04-06 20:35:00  145316   18.517
# 329        NaN    Male 2010-01-27 2020-04-06 02:57:00   87760   14.987
# 481        NaN  Female 2013-04-27 2020-04-06 06:40:00   93847    1.085
#
#      Senior Management                  Team
# 101               True             Marketing
# 440               True       Client Services
# 137              False          Distribution
# 141               True               Product
# 302               True       Human Resources
# ..                 ...                   ...
# 149               True          Distribution
# 157               True               Product
# 269               True       Human Resources
# 329               True           Engineering
# 481               True  Business Development
#
# [769 rows x 8 columns]

# %%
df.drop_duplicates(subset=['First Name','Team'], inplace=True)
df.head(2)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2020-04-06 10:20:00   61602   11.849
# 440      Aaron   Male 1990-07-22 2020-04-06 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 440               True  Client Services

# %%
len(df)
# Out:
# 769

# %% [markdown]
# ## The .unique() and .nunique() methods

# %%
df = pd.read_csv('pandas/employees.csv', parse_dates=['Start Date','Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team']=df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-04-06 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-04-06 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-04-06 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df['Gender'].unique()
# Out:
# [Male, Female, NaN]
# Categories (2, object): [Male, Female]

# %%
df['Team'].unique()
# Out:
# [Marketing, NaN, Finance, Client Services, Legal, ..., Engineering, Business Development, Human Resources, Sales, Distribution]
# Length: 11
# Categories (10, object): [Marketing, Finance, Client Services, Legal, ..., Business Development, Human Resources, Sales, Distribution]

# %%
len(df['Team'].unique())
# Out:
# 11

# %%
# will not count NaN values due to dropna=True
df['Team'].nunique()
df['Team'].nunique(dropna=False)
# Out:
# 11
